# %% [markdown]
# <a href="https://colab.research.google.com/github/get-programmed/Power_BI_Repo_LinkedIn/blob/main/Diwali_Sales/Pandas_Example_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python Common Functions With Example**

# %%
# Import the needed library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import textwrap

# %% [markdown]
# *   pandas: a library used for data manipulation and analysis.
# *   numpy: a library used for scientific computing and array operations.
# *   matplotlib.pyplot: a library used for creating visualizations.
# ---
# ---

# %%
df = pd.read_csv(r"https://raw.githubusercontent.com/get-programmed/Python_For_Analysis/main/Datasets/Diwali%20Sales%20Data.csv",header=0,encoding='latin1')

# %% [markdown]
# 1. `pd.read_csv`: This function from the Pandas library is used to read a CSV file into a DataFrame.
#
# 2. r"https://raw.githubusercontent.com/get-programmed/Python_For_Analysis/main/Datasets/Diwali%20Sales%20Data.csv": This is the URL of the CSV file that you want to read. The `r` before the string indicates that it is a raw string, meaning that backslashes are not treated as escape characters.
#
# 3. header=0: This argument specifies that the first row of the CSV file contains the column names.
#
# 4. encoding='latin1': This argument specifies the character encoding of the CSV file. In this case, it is set to latin1, which is commonly used for data from Western Europe.
#
# ---
# ---
#
#
# *   A DataFrame is a two-dimensional data structure that stores data in rows and columns(Tabular data).
# *   A Data Series is a one-dimensional data structure that stores data in a sequence.
#
#
#
# ---
# ---

# %%
df.shape
# Out:
# (11251, 15)

# %% [markdown]
# This tells us that the DataFrame has 3 rows and 2 columns.
#
# You can use the `df.shape` attribute to get a quick overview of the size of your DataFrame. This can be helpful when you are working with large datasets and you need to know how many rows and columns you are dealing with.
#
# ---
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# The `df.info()` method in Pandas displays a concise summary of the DataFrame, including:
#
# The number of rows and columns
# The data type of each column
# The number of non-null values in each column
# The memory usage of the DataFrame
#
# ---
# ---

# %%
df.drop(['Status','unnamed1'], axis = 1, inplace = True)

# %% [markdown]
# The `inplace` argument in Python functions specifies whether the function modifies the original object or creates a copy.
#
# When `inplace` is set to `True`, the function modifies the original object and returns None. This can be more efficient than creating a new copy of the object, especially for large datasets. However, it also means that the original object is modified, which can be undesirable in some cases.
#
# When `inplace` is set to `False` (the default), the function creates a copy of the object and returns the copy. This ensures that the original object is not modified, but it can be less efficient.
#
# ---
# ---

# %%
pd.isnull(df)

df.isnull()
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %% [markdown]
# The main difference between `pd.isnull(df)` and `df.isnull()` is that `pd.isnull(df)` checks for missing values in the entire DataFrame, while `df.isnull()` only checks for missing values in the current DataFrame.
#
# `pd.isnull(df)`:
# * Takes a DataFrame as an argument.
# * Returns a DataFrame of the same size as the input DataFrame, where each element is replaced with either True (missing data) or False (non-missing data).
# * Useful when you want to check for missing values in the entire DataFrame, including column names and index.
#
# `df.isnull()`:
# * Can be called on a DataFrame directly.
# * Returns a DataFrame of the same size as the input DataFrame, where each element is replaced with either True (missing data) or False (non-missing data).
# * Only checks for missing values in the data portion of the DataFrame, excluding column names and index.
#
# ---
# ---

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %% [markdown]
# The `pd.isnull(df).sum()` method in Pandas is used to count the number of missing values in each column of a DataFrame. It returns a Series object where the index is the column name and the values are the count of missing values in each column.
#
# ---
# ---

# %%
df.shape
# Out:
# (11251, 13)

# %%
# You can use dfs = df.dropna but it will create a copy of your data
df.dropna(inplace = True)

# %% [markdown]
# The `df.dropna(inplace = True)` method in Pandas is used to remove any rows that contain missing values `(NaN)` from a DataFrame. It modifies the original DataFrame inplace, meaning that the changes are permanent.
#
# ---
# The main difference between `df.dropna(inplace = True)` and dfs = df.dropna is that `df.dropna(inplace = True)` modifies the original DataFrame, while `dfs = df.dropna` creates a copy of the DataFrame with the dropped rows.
#
# `df.dropna(inplace = True)` :
# * Modifies the original DataFrame inplace.
# * Returns None.
#
# `dfs = df.dropna` :
# * Creates a copy of the DataFrame with the dropped rows.
# * Returns the new DataFrame.
#
#
# ---
# ---

# %%
df.shape
# Out:
# (11239, 13)

# %%
# Change datatype from float to int for "Amount"
df['Amount'] = df['Amount'].astype('int')

df['Amount'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# `.astype('int')` is a method that converts the data type of the selected column to the specified type, in this case, `int`
#
# ---
# ---

# %%
# To show the columns
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# Rename column, df.rename(columns={'Marital_Status': 'Married'}, inplace=True) this is permanent change, the below one temporary
df.rename(columns={'Marital_Status':'Married'})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Married  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28        0
# 1      1000732       Kartik  P00110942      F     26-35   35        1
# 2      1001990        Bindu  P00118542      F     26-35   35        1
# 3      1001425       Sudevi  P00237842      M      0-17   16        0
# 4      1000588         Joni  P00057942      M     26-35   28        1
# ...        ...          ...        ...    ...       ...  ...      ...
# 11246  1000695      Manning  P00296942      M     18-25   19        1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33        0
# 11248  1001209        Oshin  P00201342      F     36-45   40        0
# 11249  1004023       Noonan  P00059442      M     36-45   37        0
# 11250  1002744      Brumley  P00281742      F     18-25   19        0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %% [markdown]
# There are two other methods you can use to rename columns in a Pandas DataFrame without using inplace=True:
#
# 1. Using the `.assign()` method:
#
# `df = df.assign(Married=df['Marital_Status'])`
# This method creates a new DataFrame with the new column name, while leaving the original DataFrame unchanged.
#
# 2. Using dictionary assignment:
#
# `df['Married'] = df['Marital_Status']`
#
# This method directly assigns the values from the `Marital_Status` column to a new column named `Married`.
#
# ---
# ---

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %% [markdown]
# The `df.describe()` method in Pandas generates descriptive statistics for the DataFrame, including:
#
#
#
# *   The count of values
# *   The mean
# *   The standard deviation
# *   The minimum value
# *   The 25th percentile
# *   The 50th percentile (median)
# *   The 75th percentile
# *   The maximum value
# *   List item
# *   List item
#
# By default, the df.describe() method only calculates descriptive statistics for the numeric columns in the DataFrame. However, you can also specify which columns to include or exclude using the include and exclude arguments.
#
# ---
# ---

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# ## **Gender**

# %%
# Analysis on the bases of gender and count of buyers

# ax = sns.countplot(x = 'Gender',data = df) #without Color

# ax = sns.countplot(x = 'Gender',data = df, palette=sns.color_palette("Set1"))
# ax = sns.countplot(x = 'Gender',data = df, palette="hls")
ax = sns.countplot(x = 'Gender', data = df, hue='Gender', palette={'F': 'red', 'M': 'green'}, width =0.2)

for bars in ax.containers:
  ax.bar_label(bars)

# %% [markdown]
# Female buyers are more then Male

# %% [markdown]
# ## Age group

# %%
# Analysis on the bases of age group and gender(Grouped)

sns.countplot(data = df, x = 'Age Group', palette="hls")
# Out:
# <ipython-input-16-5e097163ac62>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = df, x = 'Age Group', palette="hls")
# <Axes: xlabel='Age Group', ylabel='count'>

# %% [markdown]
# People Of Age group 26-35 buys more

# %%
# Analysis on the bases of age group and gender

ay = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')

for bars in ay.containers:
  ay.bar_label(bars)
# Remove legend
# sns.countplot(data = df, x = 'Age Group', hue = 'Gender', legend=False)

# %% [markdown]
# breaking down on gender, age group it found that age group 26-35 female buyers are more

# %%
# Analysis on the bases of age group and gender, sort by count

ay = sns.countplot(data = df, x = 'Age Group', hue = 'Gender', order=df.groupby('Age Group')['Gender'].count().sort_values(ascending=False).index)

for bars in ay.containers:
  ay.bar_label(bars)

# %% [markdown]
# ## State

# %%
# total number of orders from top 10 states

# Create a dataframe group by State
sales_state = df.groupby(['State'], as_index = False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

# Set the figure size
sns.set(rc={'figure.figsize':(20,5)})

# Create the plot
sns.barplot(data=sales_state, x = 'State', y = 'Orders', palette="hls", width =0.5)
# Out:
# <ipython-input-19-c02788562b2c>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sales_state, x = 'State', y = 'Orders', palette="hls", width =0.5)
# <Axes: xlabel='State', ylabel='Orders'>

# %% [markdown]
# Top states are UP, Maharashtra, Karnataka

# %%
# total number of orders from top 10 states

# Create a dataframe group by State
sales_state = df.groupby(['State'], as_index = False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

# Set the figure size
sns.set(rc={'figure.figsize':(20,5)})

# Create the plot
sns.barplot(data=sales_state, x = 'State', y = 'Amount', palette="hls", width =0.5)
# Out:
# <ipython-input-20-f19f055e7168>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sales_state, x = 'State', y = 'Amount', palette="hls", width =0.5)
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# ## Marital Status

# %%
# Create the countplot
ay = sns.countplot(data=df, x="Marital_Status", width=0.4, palette="hls")

# Set the figure size
sns.set(rc={"figure.figsize": (5, 4)})

# Set the x-axis tick labels
ay.set_xticklabels(["Married", "Non-Married"])

# Hide the y-axis
ay.yaxis.set_visible(False)

# Add data labels
for bars in ay.containers:
    ay.bar_label(bars)

# Display the plot
plt.show()
# Out:
# <ipython-input-21-f865e1394e12>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ay = sns.countplot(data=df, x="Marital_Status", width=0.4, palette="hls")
# <ipython-input-21-f865e1394e12>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ay.set_xticklabels(["Married", "Non-Married"])

# %% [markdown]
# Married Buyer are more then non-married

# %%
# Create a Data Frame for Marital_Status, Gender wrt Amount Spent
sales_status = df.groupby(['Marital_Status','Gender'],as_index = False)['Amount'].sum().sort_values(by = 'Amount', ascending= False)

# Create a bar plot
ay = sns.barplot(data = sales_status, x = 'Marital_Status', y= 'Amount', hue = 'Gender')

# Set the x-axis tick labels
ay.set_xticklabels(["Married", "Non-Married"])
# Out:
# <ipython-input-22-d6b5139d9415>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ay.set_xticklabels(["Married", "Non-Married"])
# [Text(0, 0, 'Married'), Text(1, 0, 'Non-Married')]

# %% [markdown]
# Femal married buyer are more them married male buyer

# %% [markdown]
# ## Occupation

# %%
# Describe the size of plot
sns.set(rc={'figure.figsize':(20,5)})

# Create a countplot, sorting by the number of occurrences
ax = sns.countplot(data = df, x= 'Occupation', order=df['Occupation'].value_counts().index, palette="hls")

#this to rotate the x axis lable
# plt.xticks(rotation=90, multialignment='left')

for bars in ax.containers:
  ax.bar_label(bars)
# Out:
# <ipython-input-23-f4ce8db815a7>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data = df, x= 'Occupation', order=df['Occupation'].value_counts().index, palette="hls")

# %% [markdown]
# Top 3 sectors are IT Sector, Healthcare, Aviation

# %%
sns.set(rc={'figure.figsize':(20,5)})

# Sort the DataFrame by 'Occupation' based on value counts
df_sorted = df.groupby('Occupation').size().reset_index(name='count').sort_values(by='count', ascending=False)

# Create a countplot, sorting by the number of occurrences
ax = sns.countplot(data=df, x='Occupation', order=df_sorted['Occupation'], palette="hls", width=0.5)

# Wrap the x-axis labels
wrapper = textwrap.TextWrapper(width=10, break_long_words=True)

# Wrap all the labels
wrapped_labels = [wrapper.fill(label) for label in df_sorted['Occupation']]

# Set the x-axis tick labels to the wrapped labels
ax.set_xticklabels(wrapped_labels)

# Show the plot
plt.show()
# Out:
# <ipython-input-24-f81ff510f97e>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='Occupation', order=df_sorted['Occupation'], palette="hls", width=0.5)
# <ipython-input-24-f81ff510f97e>:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(wrapped_labels)

# %% [markdown]
# ## Product Category

# %%
# Sort the DataFrame by 'Occupation' based on value counts
df_sorted = df.groupby('Product_Category').size().reset_index(name='count').sort_values(by='count', ascending=False)

# Create a countplot, sorting by the number of occurrences
ax = sns.countplot(data=df, x='Product_Category', order=df_sorted['Product_Category'], palette="hls", width=0.5)

# Wrap the x-axis labels
wrapper = textwrap.TextWrapper(width=10, break_long_words=True)

# Wrap all the labels
wrapped_labels = [wrapper.fill(label) for label in df_sorted['Product_Category']]

# Set the x-axis tick labels to the wrapped labels
ax.set_xticklabels(wrapped_labels)

for bars in ax.containers:
  ax.bar_label(bars)

# Show the plot
plt.show()
# Out:
# <ipython-input-25-36e98abc7cc5>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='Product_Category', order=df_sorted['Product_Category'], palette="hls", width=0.5)
# <ipython-input-25-36e98abc7cc5>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(wrapped_labels)

# %% [markdown]
# Top 3 Category are Cloths, Food and E&G

# %%
# Sort the DataFrame by 'Occupation' based on value counts
df_sorted = df.groupby(['Product_Category'],as_index = False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# Create a countplot, sorting by the number of occurrences
ax = sns.barplot(data = df_sorted, x='Product_Category', y='Amount', order=df_sorted['Product_Category'], palette="hls", width=0.5)

# Wrap the x-axis labels
wrapper = textwrap.TextWrapper(width=10, break_long_words=True)

# Wrap all the labels
wrapped_labels = [wrapper.fill(label) for label in df_sorted['Product_Category']]

# Set the x-axis tick labels to the wrapped labels
ax.set_xticklabels(wrapped_labels)

# Show the plot
plt.show()
# Out:
# <ipython-input-26-a20b07a092f9>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data = df_sorted, x='Product_Category', y='Amount', order=df_sorted['Product_Category'], palette="hls", width=0.5)
# <ipython-input-26-a20b07a092f9>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(wrapped_labels)

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### Married women age group 26-35 yrs from UP, Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food Clothing and Electronics category
